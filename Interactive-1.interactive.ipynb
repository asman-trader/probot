# %%
# Out:
# Running cells with '.venv (Python 3.12.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Aseman/OneDrive/Desktop/py-code/1probot/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
